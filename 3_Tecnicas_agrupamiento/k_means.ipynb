# %% [markdown]
# Agrupación en clústeres k-means

# %% [markdown]
# Técnica de aprendizaje automático no supervisado que se utiliza para identificar grupos de objetos de datos en un conjunto de datos.

# %%
#Librerias
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# 1. Carga el archivo clusters.csv en el dataframe

# %%
df = pd.read_csv('clusters.csv',delimiter=";")
df.head()
# Out:
#    Latitud  Longitud
# 0   8.9784  -83.0378
# 1   8.9786  -83.0833
# 2   9.0236  -83.0377
# 3   8.9786  -83.0833
# 4   9.0246  -83.3104

# %% [markdown]
# 2. Divide los datos en cuatro grupos utilizando k-means de scikit-learn.

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(df)
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=4)

# %% [markdown]
# 3. Haz una predicción basada en este modelo(k-means)

# %%
y_kmeans = kmeans.predict(df)
cluster_centers = kmeans.cluster_centers_

# %% [markdown]
# 4. Imprime las coordenadas del centroide de cada grupo.

# %% [markdown]
# 5. Grafica los resultados y los centros de las agrupaciones determinados por el estimador de k-means.

# %%
plt.scatter(df['Latitud'], df['Longitud'], c=y_kmeans, s=20)
plt.scatter(cluster_centers[:,0], cluster_centers[:,1], c='red', s=200)
plt.xlabel('Latitud')
plt.ylabel('Longitud')
# Out:
# Text(0, 0.5, 'Longitud')
